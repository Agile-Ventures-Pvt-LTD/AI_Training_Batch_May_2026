# %%
from dotenv import load_dotenv
load_dotenv()
import os
os.environ['HF_TOKEN'] = os.getenv('HF_TOKEN')

# %%
from pydantic_ai import Embedder

# Model is downloaded from Hugging Face on first use
embedder = Embedder('sentence-transformers:google/embeddinggemma-300m')


async def main():
    result = await embedder.embed_query('Hello world')
    print(result)
    #> 768

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from sentence-transformers) (4.17.0)
# Requirement already satisfied: tqdm in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from sentence-transformers) (4.68.3)
# Requirement already satisfied: torch>=1.6.0 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: torchvision in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from sentence-transformers) (0.25.0)
# Requirement already satisfied: numpy in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from sentence-transformers) (2.4.6)
# Requirement already satisfied: scikit-learn in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from sentence-transformers) (1.9.0)
# Requirement already satisfied: scipy in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: nltk in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from sentence-transformers) (3.9.4)
# Requirement already satisfied: sentencepiece in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from sentence-transformers) (0.2.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from sentence-transformers) (0.36.2)
# Requirement already satisfied: filelock in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.29.5)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2026.6.28)
# Requirement already satisfied: requests in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.34.2)
# Requirement already satisfied: sacremoses in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.1.1)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.23.1)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2026.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.16.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from torch>=1.6.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from torch>=1.6.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from torch>=1.6.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from sympy>=1.13.3->torch>=1.6.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: click in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from nltk->sentence-transformers) (8.2.0)
# Requirement already satisfied: joblib in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from nltk->sentence-transformers) (1.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2026.6.17)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from scikit-learn->sentence-transformers) (2.23.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in C:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages (from torchvision->sentence-transformers) (12.3.0)

# %%
await main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages\pydantic_ai\embeddings\sentence_transformers.py:18
#      17     import torch
# ---> 18     from sentence_transformers import SentenceTransformer
#      19 except ImportError as _import_error:
#
# File c:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages\sentence_transformers\__init__.py:3
#       2 __MODEL_HUB_ORGANIZATION__ = 'sentence-transformers'
# ----> 3 from .datasets import SentencesDataset, ParallelSentencesDataset
#       4 from .LoggingHandler import LoggingHandler
#
# File c:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages\sentence_transformers\datasets\__init__.py:3
#       2 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ----> 3 from .ParallelSentencesDataset import ParallelSentencesDataset
#       4 from .SentencesDataset import SentencesDataset
#
# File c:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages\sentence_transformers\datasets\ParallelSentencesDataset.py:4
#       3 import gzip
# ----> 4 from .. import SentenceTransformer
#       5 from ..readers import InputExample
#
# File c:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:12
#      11 import transformers
# ---> 12 from huggingface_hub import HfApi, HfFolder, Repository, hf_hub_url, cached_download
#      13 import torch
#
# ImportError: cannot import name 'cached_download' from 'huggingface_hub' (c:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages\huggingface_hub\__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 await main()
#
# Cell In[2], line 8, in main()
#       7 async def main():
# ----> 8     result = await embedder.embed_query('Hello world')
#       9     print(result)
#      10     #> 768
#
# File c:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages\pydantic_ai\embeddings\__init__.py:282, in Embedder.embed_query(self, query, settings)
#     266 async def embed_query(
#     267     self, query: str | Sequence[str], *, settings: EmbeddingSettings | None = None
#     268 ) -> EmbeddingResult:
#     269     """Embed one or more query texts.
#     270
#     271     Use this method when embedding search queries that will be compared against document embeddings.
#    (...)    280         and metadata about the operation.
#     281     """
# --> 282     return await self.embed(query, input_type='query', settings=settings)
#
# File c:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages\pydantic_ai\embeddings\__init__.py:320, in Embedder.embed(self, inputs, input_type, settings)
#     302 async def embed(
#     303     self, inputs: str | Sequence[str], *, input_type: EmbedInputType, settings: EmbeddingSettings | None = None
#     304 ) -> EmbeddingResult:
#     305     """Embed text inputs with explicit input type specification.
#     306
#     307     This is the low-level embedding method. For most use cases, prefer
#    (...)    318         and metadata about the operation.
#     319     """
# --> 320     model = self._get_model()
#     321     settings = merge_embedding_settings(self._settings, settings)
#     322     return await model.embed(inputs, input_type=input_type, settings=settings)
#
# File c:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages\pydantic_ai\embeddings\__init__.py:385, in Embedder._get_model(self)
#     383     model_ = some_model
#     384 else:
# --> 385     model_ = self._model = infer_embedding_model(self.model)
#     387 instrument = self.instrument
#     388 if instrument is None:
#
# File c:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages\pydantic_ai\embeddings\__init__.py:131, in infer_embedding_model(model, provider_factory)
#     129     return GoogleEmbeddingModel(model_name, provider=provider)
#     130 elif model_kind == 'sentence-transformers':
# --> 131     from .sentence_transformers import SentenceTransformerEmbeddingModel
#     133     return SentenceTransformerEmbeddingModel(model_name)
#     134 elif model_kind == 'voyageai':
#
# File c:\Users\Vikash Kumar\Desktop\New folder\.venv\Lib\site-packages\pydantic_ai\embeddings\sentence_transformers.py:20
#      18     from sentence_transformers import SentenceTransformer
#      19 except ImportError as _import_error:
# ---> 20     raise ImportError(
#      21         'Please install `sentence-transformers` to use the Sentence-Transformers embeddings model, '
#      22         'you can use the `sentence-transformers` optional group — '
#      23         'pip install "pydantic-ai-slim[sentence-transformers]"'
#      24     ) from _import_error
#      27 class SentenceTransformersEmbeddingSettings(EmbeddingSettings, total=False):
#      28     """Settings used for a Sentence-Transformers embedding model request.
#      29
#      30     All fields from [`EmbeddingSettings`][pydantic_ai.embeddings.EmbeddingSettings] are supported,
#      31     plus Sentence-Transformers-specific settings prefixed with `sentence_transformers_`.
#      32     """
#
# ImportError: Please install `sentence-transformers` to use the Sentence-Transformers embeddings model, you can use the `sentence-transformers` optional group — pip install "pydantic-ai-slim[sentence-transformers]"
