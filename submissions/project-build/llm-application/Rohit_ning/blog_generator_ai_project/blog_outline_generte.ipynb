# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from groq_client import run_case, save_output, call_llm
from prompts import blog_outline_prompts

# %%
outline = call_llm(blog_outline_prompts)

# %%
outline_blog_result = run_case("blog_outline", blog_outline_prompts)


outline_blog_result
# Out:
# {'title': 'Revolutionizing Marketing Productivity: How Generative AI Can Transform Blog Creation',
#  'outline': [{'section_heading': 'Introduction to AI-Powered Blog Generation',
#    'section_purpose': 'Introduce the concept of using Generative AI for blog creation and its potential to improve marketing productivity',
#    'key_points_to_cover': ['Current challenges in manual blog creation',
#     'Introduction to Generative AI and its applications in content creation',
#     'Benefits of using AI-powered blog generation tools']},
#   {'section_heading': 'Understanding the Blog Generation Process',
#    'section_purpose': 'Explain the process of how AI-powered blog generation tools work and the importance of structured inputs',
#    'key_points_to_cover': ['Overview of the blog generation process',
#     'Importance of structured inputs from marketing users',
#     'Role of business context and blog intent in AI-powered blog generation']},
# ...
