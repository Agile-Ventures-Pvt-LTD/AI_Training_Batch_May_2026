# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from groq_client import run_case, save_output, call_llm
from prompts import Zero_shot_prompt_Blog_intent

# %%
 intent = call_llm(Zero_shot_prompt_Blog_intent)

# %%
result = run_case("zero_shot", Zero_shot_prompt_Blog_intent)


result
# Out:
# {'blog_intent': 'SEO_INFORMATIONAL',
#  'target_reader_maturity': 'BEGINNER',
#  'recommended_content_angle': '',
#  'reasoning_summary': ''}
