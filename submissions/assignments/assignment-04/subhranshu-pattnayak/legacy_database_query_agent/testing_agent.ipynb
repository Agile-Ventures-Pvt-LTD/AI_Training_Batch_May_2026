# %%
from legacy_sql_agent import SQLAgent

# %%
agent = SQLAgent()

# %%
query_1 = "Which customer made the largest payment?"

# %%
response_1 = agent.invoke(query_1)

# %%
print(response_1.content)
# Out:
# The customer who has paid the most overall is:
#
# | **customer_id**                              | **customer_unique_id**                     | **Total amount paid** |
# |----------------------------------------------|--------------------------------------------|-----------------------|
# | 1617b1357756262bfa56ab541c47bc16            | 0a0a92112bd4c708ca5fde585afaa872          | **$13,664.08** |
#
# This figure is the sum of all payment values (`payment_value`) recorded in the **order_payments** table for every order placed by that customer. It represents the highest cumulative payment among all customers in the dataset.

# %%
query_2 = "What is the city of the highest buyer of the most selling product."

# %%
response_2 = agent.invoke(query_2)

# %%
print(response_2.content)
# Out:
# The product that sold the most overall is
#
# - **product_id:** `aca2eb7d00ea1a7b8ebd4e68314663af` (527 order‑item rows).
#
# Among the customers who bought this product, the one with the highest purchase count is
#
# - **customer_id:** `5a7346263920ecab0f88da703bbaf3b1` (bought the product 4 times).
#
# Looking up this customer’s address in the **customers** table gives:
#
# - **city:** **Rio de Janeiro** (state RJ).
#
# **Answer:** The city of the highest‑buying customer for the top‑selling product is **Rio de Janeiro**.
