# %%
from sql_agent import SQLAgent

# %%
agent = SQLAgent()

# %%
query_1 = "Which customer made the largest payment?"

# %%
response_1 = agent.invoke(query_1)

# %%
print(response_1.content)
# Out:
# The customer who made the largest total payment is:
#
# - **Customer ID:** `1617b1357756262bfa56ab541c47bc16`
# - **Customer Unique ID:** `0a0a92112bd4c708ca5fde585afaa872`
# - **Total Payment Amount:** **$13,664.08**
#
# This customer’s cumulative payments across all of their orders sum to the highest amount in the dataset.

# %%
query_2 = "What is the city of the highest buyer of the most selling product."

# %%
response_2 = agent.invoke(query_2)

# %%
print(response_2.content)
# Out:
# **Result**
#
# The product that sold the most overall is
#
# | product_id                              | total units sold |
# |----------------------------------------|-----------------|
# | `aca2eb7d00ea1a7b8ebd4e68314663af`      | 527             |
#
# For this product, the customers who bought the highest number of units each purchased **4** units. Those top‑buying customers are:
#
# | customer_id                           | city            | units bought |
# |---------------------------------------|----------------|--------------|
# | `1a01dcde907c2725b4170084bebc53e0`    | **São Paulo**  | 4 |
# | `5a7346263920ecab0f88da703bbaf3b1`    | **Rio de Janeiro** | 4 |
#
# Because the highest purchase quantity (4) is tied, the “city of the highest buyer” includes **both São Paulo and Rio de Janeiro**. If a single city must be chosen, either one is correct; the data shows that the top buyers are located in those two cities.
