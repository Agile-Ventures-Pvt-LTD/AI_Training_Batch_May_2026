# %% [markdown]
# # PROMPT ENGINEERING

# %% [markdown]
# ## Zero-Shot Prompting

# %% [markdown]
# ### Case 1.1 - Zero-Shot Risk Classification for Vendor Onboardin

# %%
from prompts import zero_shot_vendor_prompt
from runner import run_prompt

response = run_prompt(zero_shot_vendor_prompt,"outputs/Case_1_1_Zero-Shot Risk Classification for Vendor Onboarding.json")
print(response)
# Out:
# Saved output to outputs/Case_1_1_Zero-Shot Risk Classification for Vendor Onboarding.json
# ...

# %% [markdown]
# ### Case 1.2 - Zero-Shot Executive Decision Memo

# %%
from prompts import zero_shot_executive_prompt
from runner import run_prompt

response = run_prompt(zero_shot_executive_prompt,"outputs/Case_1_2_Zero-Shot Executive Decision Memo.json")
print(response)
# Out:
# Saved output to outputs/Case_1_2_Zero-Shot Executive Decision Memo.json
# ...

# %% [markdown]
# ## Few-Shot Prompting

# %% [markdown]
# ### Case 2.1 - Few-Shot Customer Ticket Intent Classification

# %%
from prompts import few_shot_ticket_prompt
from runner import run_prompt

response = run_prompt(few_shot_ticket_prompt,"outputs/Case_2_1_Few-Shot Customer Ticket Intent Classification.json")
print(response)
# Out:
# Saved output to outputs/Case_2_1_Few-Shot Customer Ticket Intent Classification.json
# ...

# %% [markdown]
# ### Case 2.2 - Few-Shot Transformation from Requirement to API Contract

# %%
from prompts import few_shot_api_prompt
from runner import run_prompt

response = run_prompt(few_shot_api_prompt,"outputs/Case_2_2_Few-Shot Transformation from Requirement to API Contract.json")
print(response)
# Out:
# Saved output to outputs/Case_2_2_Few-Shot Transformation from Requirement to API Contract.json
# ...

# %% [markdown]
# ## Chain-of-Thought Style Reasoning

# %% [markdown]
# ### Case 3.1 - Business ROI Decision with Hidden Trade-Offs

# %%
from prompts import cot_roi_prompt
from runner import run_prompt

response = run_prompt(cot_roi_prompt,"outputs/Case_3_1_Business ROI Decision with Hidden Trade-Offs.json")
print(response)
# Out:
# Saved output to outputs/Case_3_1_Business ROI Decision with Hidden Trade-Offs.json
# ...

# %% [markdown]
# ### Case 3.2 - Root Cause Analysis for ML Model Performance Drop

# %%
from prompts import cot_ml_root_cause_prompt
from runner import run_prompt

response = run_prompt(cot_ml_root_cause_prompt,"outputs/Case_3_2_Root Cause Analysis for ML Model Performance Drop.json")
print(response)
# Out:
# Saved output to outputs/Case_3_2_Root Cause Analysis for ML Model Performance Drop.json
# ...

# %% [markdown]
# ## LLM-as-Judge

# %% [markdown]
# ### Case 4.1 - Judging AI-Generated Customer Support Responses

# %%
from prompts import llm_judge_support_prompt
from runner import run_prompt

response = run_prompt(llm_judge_support_prompt,"outputs/Case_4_1_Judging AI-Generated Customer Support Responses.json")
print(response)
# Out:
# Saved output to outputs/Case_4_1_Judging AI-Generated Customer Support Responses.json
# ...

# %% [markdown]
# ### Case 4.2 - Judging Code Explanation Quality

# %%
from prompts import llm_judge_python_prompt
from runner import run_prompt

response = run_prompt(llm_judge_python_prompt,"outputs/Case_4_2_Judging Code Explanation Quality.json")
print(response)
# Out:
# Saved output to outputs/Case_4_2_Judging Code Explanation Quality.json
# ...

# %% [markdown]
# ## Self-Consistency

# %% [markdown]
# ### Case 5.1 - Self-Consistency for Complex Policy Interpretation

# %%
from prompts import self_consistency_policy_prompt
from runner import run_prompt

response = run_prompt(self_consistency_policy_prompt,"outputs/Case_5_1_Self-Consistency for Complex Policy Interpretation.json")
print(response)
# Out:
# Saved output to outputs/Case_5_1_Self-Consistency for Complex Policy Interpretation.json
# ...

# %% [markdown]
# ### Case 5.2 - Self-Consistency for Logical Deduction

# %%
from prompts import self_consistency_security_prompt
from runner import run_prompt

response = run_prompt(self_consistency_security_prompt,"outputs/Case_5_2_Self-Consistency for Cybersecurity Risk Analysis.json")
print(response)
# Out:
# Saved output to outputs/Case_5_2_Self-Consistency for Cybersecurity Risk Analysis.json
# {'runs': [], 'risk_level_votes': {}, 'final_risk_level': 'MEDIUM', 'disagreement_analysis': '', 'final_reasoning_summary': 'The login was at 8:15\u202fPM, outside business hours (9\u202fAM‑6\u202fPM). One MFA failure occurred, triggering rule\u202f2 and flagging MEDIUM risk. Rule\u202f1 does not apply because the login country (Germany) is already known and is also a known VPN country, so no HIGH risk is set despite 8 file downloads. Since both HIGH and MEDIUM are not true, there is no escalation to CRITICAL. Therefore, the final risk level is MEDIUM.'}

# %% [markdown]
# ## Tree-of-Thought

# %% [markdown]
# ### Case 6.1 - Selecting the Best AI Automation Use Cass

# %%
from prompts import tree_of_thought_usecase_prompt
from runner import run_prompt

response = run_prompt(tree_of_thought_usecase_prompt,"outputs/Case_6_1_Tree of Thought for AI Strategy Evaluation.json")
print(response)
# Out:
# Saved output to outputs/Case_6_1_Tree of Thought for AI Strategy Evaluation.json
# ...

# %% [markdown]
# ### Case 6.2 - Tree-of-Thought Architecture Selection

# %%
from prompts import tree_of_thought_architecture_prompt
from runner import run_prompt

response = run_prompt(tree_of_thought_architecture_prompt,"outputs/Case_6_2_Tree of Thought for AI Systems Architecture.json")
print(response)
# Out:
# Saved output to outputs/Case_6_2_Tree of Thought for AI Systems Architecture.json
# ...

# %% [markdown]
# ## Rephrase-and-Respond

# %% [markdown]
# ### Case 7.1 - Ambiguous Business Request Rewriting

# %%
from prompts import rephrase_business_prompt
from runner import run_prompt

response = run_prompt(rephrase_business_prompt,"outputs/Case_7_1_Rephrase & Respond for Business Problem.json")
print(response)
# Out:
# Saved output to outputs/Case_7_1_Rephrase & Respond for Business Problem.json
# ...

# %% [markdown]
# ### Case 7.2 - Rephrase and Respond for Poorly Written Technical Requirement

# %%
from prompts import rephrase_technical_prompt
from runner import run_prompt

response = run_prompt(rephrase_technical_prompt,"outputs/Case_7_2_Rephrase & Respond for Technical Requirement.json")
print(response)
# Out:
# Saved output to outputs/Case_7_2_Rephrase & Respond for Technical Requirement.json
# ...
