# %% [markdown]
# Basic Imports

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Aditya Sodani\Desktop\prompt_engineering_evaluation\.venv\Scripts\python.exe

# %%
import importlib
import os
import groq_client

importlib.reload(groq_client)

from groq_client import run_case

# %% [markdown]
# Zero shot case 1

# %%
from groq_client import run_case
from prompts import ZERO_SHOT_VENDOR_RISK_PROMPT

# %%
result = run_case(
    case_name="Zero Shot Vendor Risk",
    prompt=ZERO_SHOT_VENDOR_RISK_PROMPT,
    user_prompt = "Perform a third-party vendor risk assessment for this onboarding request.",
    output_file="outputs/zero_shot_outputs_case1.json"
)

# %%
result["parsed_response"]
# Out:
# {'risk_level': 'HIGH',
#  'key_risk_factors': ['Lack of region-specific data residency',
#   'Insufficient SOC 2 certification (only Type I)',
#   'Unclear rate limits for APIs',
#   'Usage-based pricing with potential for significant increases',
#   'Limited operational history (only 18 months) and small customer base',
#   'Customer data used for product improvement unless opted out'],
#  'missing_information': ['Clear documentation of rate limits for APIs',
#   'Detailed information on data deletion and retention policies',
#   'Explicit guarantees on data protection and privacy'],
#  'business_recommendation': "Proceed with caution and negotiate a pilot or trial period to assess the vendor's capabilities and risks. Request additional information on data protection, API rate limits, and pricing scalability. Consider mitigating controls such as data encryption, access controls, and regular security audits.",
#  'confidence_score': 0.8}

# %% [markdown]
# Zero shot case 2

# %%
from prompts import ZERO_SHOT_EXECUTIVE_DECISION_PROMPT

# %%
result = run_case(
    case_name="Zero Shot executive decision",
    prompt=ZERO_SHOT_EXECUTIVE_DECISION_PROMPT,
    user_prompt = "Evaluate this proposal and provide a final executive decision memo.",
    output_file="outputs/zero_shot_outputs_case2.json"
)

# %%
result["parsed_response"]
# Out:
# {'decision': 'APPROVE_WITH_CONDITIONS',
#  'rationale': "The proposed GenAI chatbot can potentially reduce ticket load by 35%, improving response times and customer satisfaction. With a payback period of approximately 9 months, it meets the CFO's requirement. However, concerns around compliance, data privacy, and job displacement must be addressed.",
#  'financial_considerations': ['Implementation cost: $250,000',
#   'Ongoing monthly cost: $30,000',
#   'Projected payback period: 9 months',
#   'Estimated annual cost savings: $420,000 (based on 35% reduction in ticket load)'],
#  'operational_considerations': ['Integration with existing customer support systems',
#   'Training and testing of the chatbot to ensure accuracy and effectiveness',
#   'Development of a comprehensive AI governance framework'],
#  'people_impact': ['Potential job displacement for customer support agents',
#   'Need for retraining or upskilling of agents to work alongside the chatbot',
#   'Communication plan to address concerns and ensure a smooth transition'],
#  'compliance_risks': ['Handling of personal information in customer tickets',
#   'Ensuring compliance with relevant data protection regulations',
#   'Regular audits and monitoring to mitigate risks'],
#  'conditions_for_approval': ['Development and implementation of a comprehensive AI governance framework within 6 months',
#   'Conducting a thorough data privacy impact assessment and implementing necessary safeguards',
#   'Creation of a retraining and upskilling program for customer support agents within 3 months',
#   "Regular review and evaluation of the chatbot's performance and impact on customer support operations"],
#  'final_recommendation': 'Approve the proposal with conditions, ensuring that the organization addresses the identified risks and concerns, and prioritizes the development of a comprehensive AI governance framework, data privacy safeguards, and a retraining program for customer support agents.'}

# %% [markdown]
# Few shot case 1

# %%
from prompts import Few_Shot_Customer_Ticket_Intent_Classification_prompt

# %%
result = run_case(
    case_name="Few Shot Customer Ticket Intent Classification",
    prompt=Few_Shot_Customer_Ticket_Intent_Classification_prompt,
    user_prompt="The audit logs are missing timestamps required for regulatory reporting.",
    output_file="outputs/few_shot_outputs_case1.json"
)

# %%
result["parsed_response"]
# Out:
# {'ticket': 'The audit logs are missing timestamps required for regulatory reporting.',
#  'category': 'COMPLIANCE_CONCERN',
#  'priority': 'HIGH',
#  'justification': 'The issue relates to regulatory reporting and data governance, specifically the absence of required timestamps in audit logs.'}

# %% [markdown]
# Few Shot case 2

# %%
from prompts import Few_Shot_Transformation_from_Requirement_to_API_Contract_prompt

# %%
result = run_case(
    case_name="Few-Shot Transformation from Requirement to API Contract",
    prompt=Few_Shot_Transformation_from_Requirement_to_API_Contract_prompt,
    user_prompt="Show me the sick leave rules.",
    output_file="outputs/few_shot_outputs_case2.json"
)

# %%
result["parsed_response"]
# Out:
# {'action': 'GET_POLICY',
#  'parameters': {'leave_type': 'sick'},
#  'requires_clarification': False,
#  'clarification_question': '',
#  'confidence': 0.95}

# %% [markdown]
# Chain of Thought case 1

# %%
from prompts import BUSINESS_ROI_DECISION_WITH_HIDDEN_TRADE_OFFS_PROMPT

# %%
result = run_case(
    case_name=" Business ROI Decision with Hidden Trade-Offs",
    prompt=BUSINESS_ROI_DECISION_WITH_HIDDEN_TRADE_OFFS_PROMPT,
    user_prompt="Evaluate whether this AI recommendation engine investment should be approved based on ROI and payback feasibility.",
    output_file="outputs/cot_outputs_case1.json"
)

# %%
result["parsed_response"]
# Out:
# {'incremental_revenue_range': '$80,000 - $140,000',
#  'incremental_gross_profit_range': '$32,000 - $56,000',
#  'monthly_net_benefit_range': '$2,000 - $26,000',
#  'payback_period_range_months': '7 - 9 months',
#  'decision': 'APPROVE',
#  'reasoning_summary': 'The investment is expected to generate a positive net benefit, with a payback period within the required 12 months after go-live.',
#  'key_assumptions': ['The revenue uplift ranges are achievable and sustainable.',
#   'The implementation cost and monthly operating costs are accurate.',
#   'The gross margin remains constant at 40%.']}

# %% [markdown]
# Chain of thought case 2

# %%
from prompts import ROOT_CAUSE_ANALYSIS_FOR_ML_MODEL_PERFORMANCE_DROP_PROMPT

# %%
result = run_case(
    case_name="Root Cause Analysis for ML Model Performance Drop",
    prompt=ROOT_CAUSE_ANALYSIS_FOR_ML_MODEL_PERFORMANCE_DROP_PROMPT,
    user_prompt = "Perform a structured root cause analysis for the observed fraud detection model performance degradation.",
    output_file="outputs/cot_outputs_case2.json"
)

# %%
result["parsed_response"]
# Out:
# {'most_likely_causes': ['Concept Drift due to changed fraud patterns after promotional campaign',
#   'Data Drift due to significant shift in feature distribution for transaction_amount'],
#  'evidence': ['Precision dropped more significantly than recall',
#   'Transaction volume increased by 30%',
#   'New payment channel introduced',
#   'Feature distribution for transaction_amount shifted significantly',
#   'Fraud patterns changed after promotional campaign'],
#  'less_likely_causes': ['Pipeline Failure', 'Threshold Miscalibration'],
#  'recommended_diagnostics': ['Monitor and analyze feature distributions for other relevant features',
#   'Assess the impact of the new payment channel on model performance',
#   'Evaluate the effectiveness of the current model in detecting new fraud patterns',
#   'Investigate the relationship between transaction volume and model performance'],
#  'short_term_actions': ['Implement a temporary threshold adjustment to balance precision and recall',
#   'Closely monitor model performance and adjust as needed'],
#  'long_term_actions': ['Retrain the model using updated data that reflects the changed fraud patterns and feature distributions',
#   'Consider incorporating additional features that can help detect new fraud patterns',
#   'Regularly review and update the model to ensure it remains effective in detecting fraud'],
#  'reasoning_summary': 'The observed performance degradation is likely due to concept drift and data drift caused by changes in fraud patterns and feature distributions. A combination of short-term adjustments and long-term model updates is recommended to address the issue.'}

# %% [markdown]
# LLM as a judge case 1

# %%
from prompts import LLM_AS_JUDGE_CUSTOMER_SUPPORT_RESPONSE_EVALUATION_PROMPT

# %%
result = run_case(
    case_name="Judging AI-Generated Customer Support Responses",
    prompt=LLM_AS_JUDGE_CUSTOMER_SUPPORT_RESPONSE_EVALUATION_PROMPT,
    user_prompt = "Score and compare the two responses for customer support quality and policy compliance.",
    output_file="outputs/llm_as_a_judge_outputs_case1.json"
)

# %%
result["parsed_response"]
# Out:
# {'response_a': {'scores': {'empathy': 2,
#    'helpfulness': 2,
#    'professionalism': 4,
#    'policy_compliance': 4,
#    'specificity': 2},
#   'strengths': ['Maintains a professional tone'],
#   'weaknesses': ['Lacks empathy',
#    'Does not provide actionable guidance',
#    'Vague response']},
#  'response_b': {'scores': {'empathy': 5,
#    'helpfulness': 5,
#    'professionalism': 5,
#    'policy_compliance': 5,
#    'specificity': 5},
#   'strengths': ['Acknowledges customer frustration',
#    'Provides clear escalation steps',
#    'Maintains professionalism'],
#   'weaknesses': []},
#  'winner': 'B',
#  'judge_reasoning_summary': 'Response B excels in empathy, helpfulness, and specificity, making it the superior choice for customer support quality and policy compliance.'}

# %% [markdown]
# LLM as a judge case 2

# %%
from prompts import LLM_AS_JUDGE_CODE_EXPLANATION_QUALITY_PROMPT

# %%
result = run_case(
    case_name="Judging Code Explanation Quality",
    prompt=LLM_AS_JUDGE_CODE_EXPLANATION_QUALITY_PROMPT,
    user_prompt = "Evaluate both explanations for technical correctness, conceptual clarity, and beginner learning quality.",
    output_file="outputs/llm_as_a_judge_outputs_case2.json"
)

# %%
result["parsed_response"]
# Out:
# {'explanation_a': {'scores': {'technical_accuracy': 5,
#    'beginner_clarity': 4,
#    'conceptual_precision': 5,
#    'educational_safety': 5,
#    'practical_usefulness': 5},
#   'issues': [],
#   'overall_score': 4.8},
#  'explanation_b': {'scores': {'technical_accuracy': 2,
#    'beginner_clarity': 3,
#    'conceptual_precision': 2,
#    'educational_safety': 2,
#    'practical_usefulness': 2},
#   'issues': ["Technically misleading statement: 'deep copy is always better'",
#    'Inaccurate memory-model explanation',
#    'Oversimplification of shallow and deep copy trade-offs'],
#   'overall_score': 2.2},
#  'winner': 'explanation_a',
#  'judge_reasoning_summary': 'Explanation A accurately describes shallow and deep copy, while Explanation B contains misleading statements and oversimplifications.'}

# %% [markdown]
# Self Consistency case 1

# %%
from prompts import SELF_CONSISTENCY_POLICY_INTERPRETATION_PROMPT

# %%
result = run_case(
    case_name="Self-Consistency Policy Interpretation",
    prompt=SELF_CONSISTENCY_POLICY_INTERPRETATION_PROMPT,
    user_prompt="Perform multiple independent policy interpretations and determine the most consistent reimbursable amount for this travel expense claim.",
    output_file="outputs/self_consistency_outputs_case1.json"
)

# %%
result["parsed_response"]
# Out:
# {'individual_answers': [37.5, 37.5, 37.5, 37.5, 37.5],
#  'final_reimbursable_amount': 37.5,
#  'consistency_count': {'37.50': 5},
#  'final_decision': 'The majority interpretation is that the international travel uplift applies first, increasing the daily meal limit to $75, and then the same-day travel reduction applies, resulting in a 50% limit of $37.50. Since the alcohol expense is excluded, the reimbursable amount is $70 - $12 = $58, which is below the 50% limit of $37.50 is incorrect, the correct calculation is $75 * 0.5 = $37.50, and the claim is $70 - $12 = $58, so the correct answer is the minimum between $58 and $37.50, which is $37.50, after excluding alcohol.',
#  'reasoning_summary': 'International travel uplift and same-day travel reduction applied correctly, with alcohol excluded and receipts provided.'}

# %% [markdown]
# Self Consistency case 2

# %%
from prompts import SELF_CONSISTENCY_LOGICAL_DEDUCTION_RISK_CLASSIFICATION_PROMPT

# %%
result = run_case(
    case_name="Self-Consistency Logical Deduction Risk Classification",
    prompt=SELF_CONSISTENCY_LOGICAL_DEDUCTION_RISK_CLASSIFICATION_PROMPT,
    user_prompt="Perform multiple independent security rule evaluations and determine the most consistent final risk classification for this access event.",
    output_file="outputs/self_consistency_outputs_case2.json"
)

# %%
result["parsed_response"]
# Out:
# {'runs': [{'risk_level': 'MEDIUM',
#    'reason': 'Login outside business hours and MFA failure'},
#   {'risk_level': 'MEDIUM',
#    'reason': 'Login outside business hours and MFA failure'},
#   {'risk_level': 'MEDIUM',
#    'reason': 'Login outside business hours and MFA failure'},
#   {'risk_level': 'MEDIUM',
#    'reason': 'Login outside business hours and MFA failure'},
#   {'risk_level': 'MEDIUM',
#    'reason': 'Login outside business hours and MFA failure'}],
#  'risk_level_votes': {'MEDIUM': 5, 'HIGH': 0, 'CRITICAL': 0},
#  'final_risk_level': 'MEDIUM',
#  'disagreement_analysis': 'No disagreement, all evaluations resulted in MEDIUM risk',
#  'final_reasoning_summary': 'Login occurred outside business hours and MFA failed once, but Germany is a known country, so only MEDIUM risk conditions are met'}

# %% [markdown]
# Tree of thought case 1

# %%
from prompts import TREE_OF_THOUGHT_AI_AUTOMATION_USE_CASE_SELECTION_PROMPT

# %%
result = run_case(
    case_name="Tree-of-Thought AI Automation Use Case Selection",
    prompt=TREE_OF_THOUGHT_AI_AUTOMATION_USE_CASE_SELECTION_PROMPT,
    user_prompt="Evaluate all AI automation options using a multi-branch decision analysis and recommend the best 90-day pilot candidate.",
    output_file="outputs/tot_outputs_case1.json"
)

# %%
result["parsed_response"]
# Out:
# {'options_evaluated': [{'option': 'AI Customer Support Assistant',
#    'business_value_score': 4,
#    'feasibility_score': 3,
#    'risk_score': 2,
#    'pilot_suitability_score': 4,
#    'adoption_score': 3,
#    'overall_score': 3,
#    'trade_offs': ['High potential cost savings but moderate implementation complexity and medium user adoption risk',
#     'Contains personal customer data, increasing compliance exposure and data/privacy concerns']},
#   {'option': 'AI Sales Proposal Generator',
#    'business_value_score': 4,
#    'feasibility_score': 5,
#    'risk_score': 5,
#    'pilot_suitability_score': 5,
#    'adoption_score': 5,
#    'overall_score': 5,
#    'trade_offs': ['Medium to high potential revenue impact with low data sensitivity and low user adoption risk',
#     'Requires brand and legal review, but overall feasibility and pilot suitability are high']},
#   {'option': 'AI Contract Risk Analyzer',
#    'business_value_score': 5,
#    'feasibility_score': 2,
#    'risk_score': 1,
#    'pilot_suitability_score': 2,
#    'adoption_score': 3,
#    'overall_score': 2,
#    'trade_offs': ['High business value but high implementation complexity and high legal sensitivity',
#     'Requires strong accuracy and auditability, increasing operational risk and reducing pilot suitability']},
#   {'option': 'AI Internal HR Policy Assistant',
#    'business_value_score': 3,
#    'feasibility_score': 5,
#    'risk_score': 4,
#    'pilot_suitability_score': 4,
#    'adoption_score': 5,
#    'overall_score': 4,
#    'trade_offs': ['Medium potential cost savings with low implementation complexity and low user adoption risk',
#     'High employee usage but medium sensitivity, making it a relatively balanced option']}],
#  'recommended_option': 'AI Sales Proposal Generator',
#  'why_not_others': {'AI Customer Support Assistant': 'Moderate implementation complexity and medium user adoption risk reduce its overall score',
#   'AI Contract Risk Analyzer': 'High implementation complexity, high legal sensitivity, and low pilot suitability make it less desirable',
#   'AI Internal HR Policy Assistant': 'While balanced, its overall business value and potential impact are lower compared to the recommended option'},
#  'final_recommendation': 'The AI Sales Proposal Generator is the strongest candidate for the 90-day pilot due to its high business value, feasibility, and adoption potential, combined with low risk and high pilot suitability.'}

# %% [markdown]
# Tree of thought case 2

# %%
from prompts import TREE_OF_THOUGHT_ARCHITECTURE_SELECTION_PROMPT

# %%
result = run_case(
    case_name="Tree-of-Thought Architecture Selection",
    prompt=TREE_OF_THOUGHT_ARCHITECTURE_SELECTION_PROMPT,
    user_prompt="Evaluate all architecture options using multi-branch reasoning and recommend the most practical AI document QA architecture for the startup.",
    output_file="outputs/tot_outputs_case2.json"
)

# %%
result["parsed_response"]
# Out:
# {'architecture_scores': {'OPTION A': {'Accuracy': 4,
#    'Cost': 3,
#    'Privacy & Security': 4,
#    'Timeline Feasibility': 5,
#    'Scalability': 4,
#    'Citation Reliability': 4},
#   'OPTION B': {'Accuracy': 5,
#    'Cost': 2,
#    'Privacy & Security': 3,
#    'Timeline Feasibility': 2,
#    'Scalability': 3,
#    'Citation Reliability': 5},
#   'OPTION C': {'Accuracy': 2,
#    'Cost': 5,
#    'Privacy & Security': 5,
#    'Timeline Feasibility': 5,
#    'Scalability': 5,
#    'Citation Reliability': 2},
#   'OPTION D': {'Accuracy': 5,
#    'Cost': 1,
#    'Privacy & Security': 4,
#    'Timeline Feasibility': 1,
#    'Scalability': 4,
#    'Citation Reliability': 5}},
#  'recommended_architecture': 'OPTION A',
#  'implementation_rationale': "OPTION A balances accuracy, cost, and timeline feasibility, making it the most practical choice for the startup's MVP. It leverages a simple RAG with a vector database, retrieval pipeline, and hosted LLM API, which can be delivered within the 6-week constraint.",
#  'risks': ['Hosted LLM API security risks',
#   'Vector database scalability limitations',
#   'Retrieval pipeline complexity'],
#  'mitigations': ['Implement robust security measures for hosted LLM API',
#   'Design a scalable vector database architecture',
#   'Simplify retrieval pipeline with modular components'],
#  'mvp_plan': ['Week 1-2: Design and implement vector database and retrieval pipeline',
#   'Week 3-4: Integrate hosted LLM API and develop question-answering logic',
#   'Week 5-6: Test and refine the MVP, ensuring accuracy and security']}

# %% [markdown]
# Rephrase and Respond case 1

# %%
from prompts import REPHRASE_AND_RESPOND_AMBIGUOUS_BUSINESS_REQUEST_PROMPT

# %%
result = run_case(
    case_name="Rephrase-and-Respond Ambiguous Business Request",
    prompt=REPHRASE_AND_RESPOND_AMBIGUOUS_BUSINESS_REQUEST_PROMPT,
    user_prompt="Clarify the ambiguous business request and propose a focused AI solution with measurable operational outcomes.",
    output_file="outputs/rar_outputs_case1.json"
)

# %%
result["parsed_response"]
# Out:
# {'rephrased_problem': 'Reduce manual effort in workflow processing and enhance leadership visibility into operational performance metrics',
#  'clarified_assumptions': ['Manual work is primarily related to data entry and document processing',
#   'Leadership requires real-time visibility into workflow bottlenecks and SLA performance',
#   'Current workflow processes are largely manual and prone to errors'],
#  'proposed_solution': 'Automated Document Processing and Workflow Analytics using AI-powered Optical Character Recognition (OCR) and Machine Learning (ML) algorithms',
#  'target_users': ['Operations Team', 'Leadership'],
#  'key_features': ['Automated document processing and data extraction',
#   'Real-time workflow analytics and dashboarding',
#   'Predictive modeling for bottleneck detection and SLA forecasting'],
#  'data_needed': ['Historical workflow data',
#   'Document templates and formats',
#   'SLA and performance metrics'],
#  'success_metrics': ['Reduced manual processing time by 30%',
#   'Increased accuracy in data entry by 25%',
#   'Improved SLA compliance by 20%',
#   'Reduced workflow backlog by 15%'],
#  'implementation_steps': ['Data collection and preprocessing',
#   'AI model training and testing',
#   'Integration with existing workflow systems',
#   'Pilot deployment and testing',
#   'Full-scale deployment and monitoring'],
#  'risks': ['Data quality issues impacting AI model accuracy',
#   'Integration challenges with existing systems',
#   'Change management and user adoption']}

# %% [markdown]
# Rephrase and Respond case 2

# %%
from prompts import REPHRASE_AND_RESPOND_TECHNICAL_REQUIREMENT_CLARIFICATION_PROMPT

# %%
result = run_case(
    case_name="Rephrase-and-Respond Technical Requirement Clarification",
    prompt=REPHRASE_AND_RESPOND_TECHNICAL_REQUIREMENT_CLARIFICATION_PROMPT,
    user_prompt="Clarify the vague AI product requirement and convert it into a realistic technical specification and implementation proposal.",
    output_file="outputs/rar_outputs_case2.json"
)

# %%
result["parsed_response"]
# Out:
# {'rephrased_requirement': 'Design an AI-powered document question-answering system that allows users to upload files, ask questions, and receive relevant answers with proper citation, while ensuring secure and fast processing, and providing accurate responses with a defined confidence threshold.',
#  'functional_requirements': ['Support upload of PDF, DOCX, and TXT file formats',
#   'Allow users to input questions in natural language',
#   'Provide answers with relevant citations and references',
#   'Enable users to view and manage their uploaded documents',
#   'Implement a question-answer workflow with user feedback mechanism'],
#  'non_functional_requirements': ['Response latency: < 5 seconds',
#   'Uptime expectation: 99.9% per month',
#   'Retrieval accuracy: 90% for relevant documents',
#   'Citation grounding quality: 95% for accurate references'],
#  'security_requirements': ['Implement document access controls with role-based authentication',
#   'Encrypt documents at rest and in transit using AES-256',
#   'Ensure tenant isolation for multi-tenant deployments',
#   'Comply with GDPR and HIPAA regulations for data protection'],
#  'acceptance_criteria': ['Successful upload and processing of 1000 documents within 1 hour',
#   'Average response latency < 3 seconds for 90% of user queries',
#   'User feedback mechanism captures and addresses 80% of user concerns',
#   'System uptime exceeds 99.5% during the first 6 months of operation'],
#  'recommended_solution_approach': 'Microservices-based architecture with containerized AI models, using a combination of natural language processing (NLP) and information retrieval (IR) techniques, and a cloud-based infrastructure for scalability and reliability',
#  'open_questions': ['What is the expected volume of user uploads and queries per month?',
#   'What are the specific regulatory requirements for data protection and compliance?',
#   'How will the system handle ambiguous or unclear user questions?',
#   'What is the budget for infrastructure and AI model development?']}
